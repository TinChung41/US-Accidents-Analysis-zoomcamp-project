# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('WS_DPP_csv_col.csv')
df.head()
# Out:
#   FREQ  Frequency REF_AREA Reference area COVERED_AREA  \
# 0    A     Annual       KR          Korea            0
# 1    Q  Quarterly       CH    Switzerland            3
# 2    M    Monthly       FI        Finland            3
# 3    Q  Quarterly       RO        Romania            0
# 4    M    Monthly       HK  Hong Kong SAR            0
#
#                                         Covered area RE_TYPE  \
# 0                                      Whole country       K
# 1  Capital/biggest city/financial center and suburbs       8
# 2  Capital/biggest city/financial center and suburbs       4
# 3                                      Whole country       2
# 4                                      Whole country       1
#
#                   Real estate type  RE_VINTAGE Real estate vintage  ...  \
# 0            Land for all purposes           0                 All  ...
# 1                            Flats           0                 All  ...
# ...

# %%
df.columns
df.shape
# Out:
# (333, 1127)
